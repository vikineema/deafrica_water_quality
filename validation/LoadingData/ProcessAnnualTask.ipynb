# %% [markdown]
# # Process Annual Water Quality Variables

# %% [markdown]
# This notebook demonstrates how to generate the annual water quality variables for a single task.

# %% [markdown]
# ## Getting started
#
# ### Load required python packages

# %%
# %load_ext water_quality.magics

# %%
import gc
import json
import os
import sys
import warnings

import click
import numpy as np
import toolz
import xarray as xr
from datacube import Datacube
from deafrica_tools.dask import create_local_dask_cluster
from odc import dscache
from odc.geo.xr import write_cog
from odc.stats.model import DateTimeRange

from water_quality.io import (
    check_directory_exists,
    get_filesystem,
    get_parent_dir,
    get_wq_cog_url,
    get_wq_csv_url,
    get_wq_dataset_path,
    get_wq_stac_url,
    is_s3_path,
    join_url,
)
from water_quality.logs import setup_logging
from water_quality.mapping.algorithms import WQ_vars
from water_quality.mapping.fai import geomedian_FAI
from water_quality.mapping.hue import geomedian_hue
from water_quality.mapping.instruments import (
    INSTRUMENTS_PRODUCTS,
    check_instrument_dates,
)
from water_quality.mapping.load_data import load_annual_data
from water_quality.mapping.ndvi import geomedian_NDVI
from water_quality.mapping.optical_water_type import run_OWT
from water_quality.mapping.pixel_correction import apply_R_correction
from water_quality.mapping.water_detection import (
    clear_water_mask,
    five_year_water_mask,
)
from water_quality.metadata.prepare_metadata import prepare_dataset
from water_quality.tasks import (
    create_task_id,
    filter_tasks_by_task_id,
    filter_tasks_by_tile_id,
    split_tasks,
)

# %% [markdown]
# ### Define analysis parameters

# %% [markdown]
# The expected inputs:
#
# (required_inputs):
#
# - **cache-file-path** : Path to the file database containing the tasks and datasets to be processed, generated in the `generate-tasks` step.
# - **output-directory**: Path to the directory for output COG files, CSVs, and STAC metadata.
# - **max-parallel-steps**: Total number of parallel workers/pods available to run this workflow. If running the workflow outside of Argo Workflow e.g. in a Jupyter Notebook, set this to 1. If `max-parallel-steps` is greater than 1, tasks are split equally across all available workers.
# - **worker-idx**: The sequential index (0-indexed) of the current worker (determines which task subset to process). If max parallel steps is set to 1, set this to 0.
#
# Setting **max-parallel-steps** to 1 and **worker-idx** to 0 will result in this workflow being processed in serial.
#
# - **overwrite**: If overwrite is True, tasks which have already been run and their results written to the output directory will be rerun and their output COG files and STAC metadata files be overwritten.

# %%
cache_file_path = "../../WP1.3/wq_annual_annual_2000--P25Y.db"
output_directory = "test"
max_parallel_steps = 1
worker_idx = 0
overwrite = True

# %% [markdown]
# (optional inputs)
#
# - **tasks**: A list of comma separated task IDs in the format "period/x{x:02d}/y{y:02d}" e.g. `2015--P1Y/x200/y034,2015--P1Y/x178/y095,2015--P1Y/x199/y100`. This is mutually exclusive to the `tiles` option.
# - **tiles**: A list of comma seperated tile IDs in the format "x{x:02d}/y{y:02d}" e.g `x200/y034,x178/y095,x199/y100`.

# %% [markdown]
# This notebook is designed to run a single task only, which we will specify below.

# %%
tasks = "2023--P1Y/x217/y077"
tiles = ""

# %% [markdown]
# ## Processing

# %% [markdown]
# Setup the logger for this notebook.
# By default logging is set to INFO level.

# %%
log = setup_logging()

# %% [markdown]
# Open the file database.

# %%
if is_s3_path(cache_file_path):
    local_cache_file_path = "/tmp/cachedb.db"
    fs = get_filesystem(cache_file_path, anon=False)
    fs.get(cache_file_path, local_cache_file_path)
    log.info(
        f"Downloaded cache file from {cache_file_path} to {local_cache_file_path}"
    )
    cache = dscache.open_ro(local_cache_file_path)
else:
    cache = dscache.open_ro(cache_file_path)

# %% [markdown]
# Load analysis parameters and product metadata from the file database metadata.
# This includes:
#
# - **WFTH** : The WOfS Annual frequency threshold above which a pixel is classified as general water. This used during the water detection step to generate the annual water mask.
#
# - **product name** and **product version**: This is the ODC product name and version (metadata) for the water quality variables to be processed. The convention for the product name is `wq_<frequency>` e.g. for annual water quality variables the product name  is `wq_annual`.
#
# - **instruments_to_use** : This defines instruments to be used in generating the water quality variables. The table below matches the instrument names to the ODC products loaded for the instrument. Instruments to be used have their "use" parameter set to True.
#
# | Instrument Key | Products                               |
# | -------------- | -------------------------------------- |
# | `tm_agm`       | `gm_ls5_ls7_annual`                    |
# | `oli_agm`      | `gm_ls8_annual`, `gm_ls8_ls9_annual`   |
# | `msi_agm`      | `gm_s2_annual`                         |
# | `wofs_ann`     | `wofs_ls_summary_annual`               |
# | `tirs`         | `ls5_st`, `ls7_st`, `ls8_st`, `ls9_st` |
# | `tm`           | `ls5_sr`, `ls7_sr`                     |
# | `oli`          | `ls8_sr`, `ls9_sr`                     |
# | `msi`          | `s2_l2a`                               |
#
#     When running the annual water quality variables the expected instruments are : `oli_agm`, `msi_agm`, `tm_agm`, `tirs` and `wofs_ann` with `wofs_ann` being mandatory.
#     For frequencies shorter than a year the expected instruments are: `oli`, `msi`, `tm`, `tirs` and `wofs_ann` with `wofs_ann` being mandatory.
#
# - The name and actual spatial grid used for processing.

# %%
# This should have been validated during task generation.
config = cache.get_info_dict("wq_config")
WFTH = config["WFTH"]
product_name = config["product_name"]
product_version = config["product_version"]
# Instruments to use should also have been validated
# during task generation.
cfg_instruments_to_use = config["instruments_to_use"]
# Grid properties
grid_name = config["grid_name"]
grid_spec = cache.grids[grid_name]

# %% [markdown]
# Filter the tasks present in the file database using the tasks or tiles specified in the input parameters.

# %%
input_products = {
    v: k for k, vals in INSTRUMENTS_PRODUCTS.items() for v in vals
}

# Load all tasks and split for this worker
all_task_ids = sorted([i[0] for i in cache.tiles(grid_name)])

if tasks and tiles:
    raise ValueError("Use either tasks or tiles, not both.")
else:
    if tasks or tiles:
        if tasks:
            filtered_tasks = filter_tasks_by_task_id(
                all_task_ids=all_task_ids, task_ids=tasks
            )
            filter_str = tasks
        else:
            filtered_tasks = filter_tasks_by_tile_id(
                all_task_ids=all_task_ids, tile_ids=tiles
            )
            filter_str = tiles

        if len(filtered_tasks) == 0:
            error_msg = f"No matching tasks found in the file database for the provided filter: {filter_str}."
            log.error(error_msg)
            sys.exit(1)
        else:
            log.info(
                f"Found {len(filtered_tasks)} matching task(s) "
                f"in the file database for the provided filter: {filter_str}."
            )
            tasks_to_run = split_tasks(
                filtered_tasks, max_parallel_steps, worker_idx
            )
    else:
        tasks_to_run = split_tasks(
            all_task_ids, max_parallel_steps, worker_idx
        )

if not tasks_to_run:
    log.warning(f"Worker {worker_idx} has no tasks to process. Exiting.")
    sys.exit(0)

log.info(f"Worker {worker_idx} processing {len(tasks_to_run)} task(s)")

dc = Datacube(app="ProcessAnnualWQVariables")
# Out:
# 2026-02-22 19:04:34,869 __main__ [INFO]: Found 1 matching task(s) in the file database for the provided filter: 2023--P1Y/x217/y077.
# 2026-02-22 19:04:34,870 __main__ [INFO]: Worker 0 processing 1 task(s)
# 2026-02-22 19:04:35,235 alembic.runtime.plugins [INFO]: setup plugin alembic.autogenerate.schemas
# 2026-02-22 19:04:35,236 alembic.runtime.plugins [INFO]: setup plugin alembic.autogenerate.tables
# 2026-02-22 19:04:35,236 alembic.runtime.plugins [INFO]: setup plugin alembic.autogenerate.types
# 2026-02-22 19:04:35,236 alembic.runtime.plugins [INFO]: setup plugin alembic.autogenerate.constraints
# 2026-02-22 19:04:35,237 alembic.runtime.plugins [INFO]: setup plugin alembic.autogenerate.defaults
# 2026-02-22 19:04:35,237 alembic.runtime.plugins [INFO]: setup plugin alembic.autogenerate.comments

# %%
task_id = tasks_to_run[0]

# %% [markdown]
# Get the time range and tile components of the task.

# %%
temporal_id, tile_idx, tile_idy = task_id
tile_id = (tile_idx, tile_idy)
task_id_str = create_task_id(temporal_id, tile_id)
# tile_geobox = grid_spec.tile_geobox(tile_index=tile_id)
log.info(f"Processing task: {task_id_str}")
# Out:
# 2026-02-22 19:04:35,454 __main__ [INFO]: Processing task: 2023--P1Y/x217/y077

# %%
temporal_id
# Out:
# '2023--P1Y'

# %%
# Load the instrument data generated using the prototyping WP1.2 notebooks
wp_12_data_fp = "loaded_anual_instrument_data.nc"
wp_12_data_xr = xr.open_dataset("loaded_anual_instrument_data.nc", engine='h5netcdf')
tile_geobox = wp_12_data_xr.odc.geobox
tile_geobox
# Out:
# GeoBox((170, 76), Affine(220.0, 0.0, 3473360.0,
#        0.0, 220.0, 57200.0), CRS('PROJCRS["WGS 84 / NSIDC EASE-Grid 2.0 Global",BASEGEOGCRS["WGS 84",ENSEMBLE["World Geodetic System 1984 ensemble",MEMBER["World Geodetic System 1984 (Transit)"],MEMBER["World Geodetic System 1984 (G730)"],MEMBER["World Geodetic System 1984 (G873)"],MEMBER["World Geodetic System 1984 (G1150)"],MEMBER["World Geodetic System 1984 (G1674)"],MEMBER["World Geodetic System 1984 (G1762)"],MEMBER["World Geodetic System 1984 (G2139)"],MEMBER["World Geodetic System 1984 (G2296)"],ELLIPSOID["WGS 84",6378137,298.257223563,LENGTHUNIT["metre",1]],ENSEMBLEACCURACY[2.0]],PRIMEM["Greenwich",0,ANGLEUNIT["degree",0.0174532925199433]],ID["EPSG",4326]],CONVERSION["US NSIDC EASE-Grid 2.0 Global",METHOD["Lambert Cylindrical Equal Area",ID["EPSG",9835]],PARAMETER["Latitude of 1st standard parallel",30,ANGLEUNIT["degree",0.0174532925199433],ID["EPSG",8823]],PARAMETER["Longitude of natural origin",0,ANGLEUNIT["degree",0.0174532925199433],ID["EPSG",8802]],PARAMETER["False easting",0,LENGTHUNIT["metre",1],ID["EPSG",8806]],PARAMETER["False northing",0,LENGTHUNIT["metre",1],ID["EPSG",8807]]],CS[Cartesian,2],AXIS["easting (X)",east,ORDER[1],LENGTHUNIT["metre",1]],AXIS["northing (Y)",north,ORDER[2],LENGTHUNIT["metre",1]],USAGE[SCOPE["Environmental science - used as basis for EASE grid."],AREA["World between 86°S and 86°N."],BBOX[-86,-180,86,180]],ID["EPSG",6933]]'))

# %%
tile_geobox
# Out:
# GeoBox((170, 76), Affine(220.0, 0.0, 3473360.0,
#        0.0, 220.0, 57200.0), CRS('PROJCRS["WGS 84 / NSIDC EASE-Grid 2.0 Global",BASEGEOGCRS["WGS 84",ENSEMBLE["World Geodetic System 1984 ensemble",MEMBER["World Geodetic System 1984 (Transit)"],MEMBER["World Geodetic System 1984 (G730)"],MEMBER["World Geodetic System 1984 (G873)"],MEMBER["World Geodetic System 1984 (G1150)"],MEMBER["World Geodetic System 1984 (G1674)"],MEMBER["World Geodetic System 1984 (G1762)"],MEMBER["World Geodetic System 1984 (G2139)"],MEMBER["World Geodetic System 1984 (G2296)"],ELLIPSOID["WGS 84",6378137,298.257223563,LENGTHUNIT["metre",1]],ENSEMBLEACCURACY[2.0]],PRIMEM["Greenwich",0,ANGLEUNIT["degree",0.0174532925199433]],ID["EPSG",4326]],CONVERSION["US NSIDC EASE-Grid 2.0 Global",METHOD["Lambert Cylindrical Equal Area",ID["EPSG",9835]],PARAMETER["Latitude of 1st standard parallel",30,ANGLEUNIT["degree",0.0174532925199433],ID["EPSG",8823]],PARAMETER["Longitude of natural origin",0,ANGLEUNIT["degree",0.0174532925199433],ID["EPSG",8802]],PARAMETER["False easting",0,LENGTHUNIT["metre",1],ID["EPSG",8806]],PARAMETER["False northing",0,LENGTHUNIT["metre",1],ID["EPSG",8807]]],CS[Cartesian,2],AXIS["easting (X)",east,ORDER[1],LENGTHUNIT["metre",1]],AXIS["northing (Y)",north,ORDER[2],LENGTHUNIT["metre",1]],USAGE[SCOPE["Environmental science - used as basis for EASE grid."],AREA["World between 86°S and 86°N."],BBOX[-86,-180,86,180]],ID["EPSG",6933]]'))

# %% [markdown]
# In this notebook, we will edit the tile geobox to cover a smaller test area.
# In the [Generate Tasks notebook](./GenerateTasks.ipynb) the `place-name` option was used to define the area of interest.
# We will use the same test area to edit the tile geobox.

# %%
# %%ignore
# from importlib.resources import files
# from odc.geo.geobox import GeoBox
# from odc.geo.geom import Geometry
# import geopandas as gpd
#
# place_name = "Lake_Baringo"
# places_fp = files("water_quality.data").joinpath("places.parquet")
# places_gdf = gpd.read_parquet(places_fp)
# place = places_gdf[places_gdf["name"].isin([place_name])]
# aoi_geom = Geometry(geom=place.iloc[0].geometry, crs=place.crs)
#
# tile_geobox = GeoBox.from_geopolygon(aoi_geom, crs=tile_geobox.crs, resolution=tile_geobox.resolution)
# tile_geobox

# %% [markdown]
# Validate the instruments to use from the file database metadata against the time range for the task.

# %%
temporal_range = DateTimeRange(temporal_id)
start_date = temporal_range.start.strftime("%Y-%m-%d")
end_date = temporal_range.end.strftime("%Y-%m-%d")
instruments_to_use = check_instrument_dates(  # noqa F841
    cfg_instruments_to_use,
    start_date,
    end_date,
    raise_errors=False,
)
instruments_to_use
# Out:
# 2026-02-22 19:04:35,770 water_quality.mapping.instruments [ERROR]: Instrument tm_agm has data for the date range 1990-01-01 to 2012-12-31 which is outside the requested date range of 2023-01-01 to 2023-12-31.
# Instrument use set to False
# {'oli_agm': {'use': True},
#  'oli': {'use': False},
#  'msi_agm': {'use': True},
#  'msi': {'use': False},
#  'tm_agm': {'use': False},
#  'tm': {'use': False},
#  'tirs': {'use': True},
#  'wofs_ann': {'use': True}}

# %% [markdown]
# Based on whether **overwrite** was set to True or False and if the STAC metadata file for the task exists, determine if the task will be processed.

# %%
expected_stac_path = get_wq_stac_url(
    get_wq_dataset_path(
        output_directory=output_directory,
        tile_id=tile_id,
        temporal_id=temporal_id,
        product_name=product_name,
        product_version=product_version,
    )
)
exists = check_directory_exists(expected_stac_path)
if exists and not overwrite:
    log.info(
        f"STAC file already exists for task {task_id_str} at "
        f"{expected_stac_path} and overwrite is False. "
        "Skipping processing for this task."
    )
    # continue
    sys.exit("Stopping notebook execution here")

# %% [markdown]
# Stream the datasets to be processed for the task from the file database and group the datasets by the instrument.

# %%
dss = list(cache.stream_grid_tile(task_id, grid_name))
dss = toolz.groupby(
    lambda ds: input_products[ds.product.name], dss
)

# %%
print(dss.keys())
# Out:
# dict_keys(['tirs', 'wofs_ann', 'oli_agm', 'msi_agm'])

# %%
from deafrica_tools.dask import create_local_dask_cluster
create_local_dask_cluster()
# Out:
# <Client: 'tcp://127.0.0.1:40181' processes=1 threads=4, memory=26.21 GiB>

# %% [markdown]
# Load the datasets into a dictionary, mapping instrument names to the xarray objects containing the data loaded for the task.

# %%
# Load annual data for all instruments
annual_data = load_annual_data(
    dss=dss,
    tile_geobox=tile_geobox,
    compute=False,
    dc=dc,
)
annual_data
# Out:
# 2026-02-22 19:04:37,843 water_quality.mapping.load_data [INFO]: Loading data for the instrument 'wofs_ann' ...
# 2026-02-22 19:04:37,876 water_quality.mapping.load_data [INFO]: Loading data for the instrument 'oli_agm' ...
# 2026-02-22 19:04:37,906 water_quality.mapping.load_data [INFO]: Loading data for the instrument 'msi_agm' ...
# 2026-02-22 19:04:37,947 water_quality.mapping.load_data [INFO]: Loading data for the instrument 'tirs' ...
# {'wofs_ann': <xarray.Dataset> Size: 777kB
#  Dimensions:              (time: 5, y: 170, x: 76)
#  Coordinates:
#    * time                 (time) datetime64[ns] 40B 2019-07-02T11:59:59.999999...
#    * y                    (y) float64 1kB 5.731e+04 5.753e+04 ... 9.449e+04
#    * x                    (x) float64 608B 3.473e+06 3.474e+06 ... 3.49e+06
#      spatial_ref          int32 4B 6933
#  Data variables:
#      wofs_ann_freq        (time, y, x) float32 258kB dask.array<chunksize=(5, 170, 76), meta=np.ndarray>
#      wofs_ann_clearcount  (time, y, x) float32 258kB dask.array<chunksize=(5, 170, 76), meta=np.ndarray>
#      wofs_ann_wetcount    (time, y, x) float32 258kB dask.array<chunksize=(5, 170, 76), meta=np.ndarray>
#  Attributes:
#      crs:           PROJCRS["WGS 84 / NSIDC EASE-Grid 2.0 Global",BASEGEOGCRS[...
#      grid_mapping:  spatial_ref,
#  'oli_agm': <xarray.Dataset> Size: 364kB
#  Dimensions:        (time: 1, y: 170, x: 76)
#  Coordinates:
#    * time           (time) datetime64[ns] 8B 2023-07-02T11:59:59.999999
#    * y              (y) float64 1kB 5.731e+04 5.753e+04 ... 9.427e+04 9.449e+04
#    * x              (x) float64 608B 3.473e+06 3.474e+06 ... 3.49e+06 3.49e+06
#      spatial_ref    int32 4B 6933
#  Data variables:
#      oli02_agm      (time, y, x) float32 52kB dask.array<chunksize=(1, 170, 76), meta=np.ndarray>
#      oli03_agm      (time, y, x) float32 52kB dask.array<chunksize=(1, 170, 76), meta=np.ndarray>
#      oli04_agm      (time, y, x) float32 52kB dask.array<chunksize=(1, 170, 76), meta=np.ndarray>
#      oli05_agm      (time, y, x) float32 52kB dask.array<chunksize=(1, 170, 76), meta=np.ndarray>
#      oli06_agm      (time, y, x) float32 52kB dask.array<chunksize=(1, 170, 76), meta=np.ndarray>
#      oli07_agm      (time, y, x) float32 52kB dask.array<chunksize=(1, 170, 76), meta=np.ndarray>
#      oli_agm_count  (time, y, x) float32 52kB dask.array<chunksize=(1, 170, 76), meta=np.ndarray>
#  Attributes:
#      crs:           PROJCRS["WGS 84 / NSIDC EASE-Grid 2.0 Global",BASEGEOGCRS[...
#      grid_mapping:  spatial_ref,
#  'msi_agm': <xarray.Dataset> Size: 519kB
#  Dimensions:        (time: 1, y: 170, x: 76)
#  Coordinates:
#    * time           (time) datetime64[ns] 8B 2023-07-02T11:59:59.999999
#    * y              (y) float64 1kB 5.731e+04 5.753e+04 ... 9.427e+04 9.449e+04
#    * x              (x) float64 608B 3.473e+06 3.474e+06 ... 3.49e+06 3.49e+06
#      spatial_ref    int32 4B 6933
#  Data variables:
#      msi02_agm      (time, y, x) float32 52kB dask.array<chunksize=(1, 170, 76), meta=np.ndarray>
#      msi03_agm      (time, y, x) float32 52kB dask.array<chunksize=(1, 170, 76), meta=np.ndarray>
#      msi04_agm      (time, y, x) float32 52kB dask.array<chunksize=(1, 170, 76), meta=np.ndarray>
#      msi05_agm      (time, y, x) float32 52kB dask.array<chunksize=(1, 170, 76), meta=np.ndarray>
#      msi06_agm      (time, y, x) float32 52kB dask.array<chunksize=(1, 170, 76), meta=np.ndarray>
#      msi07_agm      (time, y, x) float32 52kB dask.array<chunksize=(1, 170, 76), meta=np.ndarray>
#      msi8a_agm      (time, y, x) float32 52kB dask.array<chunksize=(1, 170, 76), meta=np.ndarray>
#      msi11_agm      (time, y, x) float32 52kB dask.array<chunksize=(1, 170, 76), meta=np.ndarray>
#      msi12_agm      (time, y, x) float32 52kB dask.array<chunksize=(1, 170, 76), meta=np.ndarray>
#      msi_agm_count  (time, y, x) float32 52kB dask.array<chunksize=(1, 170, 76), meta=np.ndarray>
#  Attributes:
#      crs:           PROJCRS["WGS 84 / NSIDC EASE-Grid 2.0 Global",BASEGEOGCRS[...
#      grid_mapping:  spatial_ref,
#  'tirs': <xarray.Dataset> Size: 22MB
#  Dimensions:      (time: 140, y: 170, x: 76)
#  Coordinates:
#    * time         (time) datetime64[ns] 1kB 2023-01-02T07:48:59.160995 ... 202...
#    * y            (y) float64 1kB 5.731e+04 5.753e+04 ... 9.427e+04 9.449e+04
#    * x            (x) float64 608B 3.473e+06 3.474e+06 ... 3.49e+06 3.49e+06
#      spatial_ref  int32 4B 6933
#  Data variables:
#      tirs_st      (time, y, x) float32 7MB dask.array<chunksize=(140, 170, 76), meta=np.ndarray>
#      tirs_emis    (time, y, x) float32 7MB dask.array<chunksize=(140, 170, 76), meta=np.ndarray>
#      tirs_st_qa   (time, y, x) float32 7MB dask.array<chunksize=(140, 170, 76), meta=np.ndarray>
#  Attributes:
#      crs:           PROJCRS["WGS 84 / NSIDC EASE-Grid 2.0 Global",BASEGEOGCRS[...
#      grid_mapping:  spatial_ref}

# %% [markdown]
# Instatiate a dictionary to store the results from each processing step.

# %%
wq_ds = {}

# %% [markdown]
# Generate the 5 year water mask using the `wofs_ann` instrument data.

# %%
wq_ds["water_mask"] = five_year_water_mask(
    annual_data=annual_data,
    compute=True,
)
gc.collect()
wq_ds["water_mask"]
# Out:
# 2026-02-22 19:04:38,305 water_quality.mapping.water_detection [INFO]: Generating 5 year water mask ...
# 2026-02-22 19:04:38,324 water_quality.mapping.water_detection [INFO]: 	Computing water mask ...
# 2026-02-22 19:04:38,894 water_quality.mapping.water_detection [INFO]: Processing complete for water mask.
# <xarray.DataArray 'water_mask' (time: 1, y: 170, x: 76)> Size: 52kB
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]],
#       shape=(1, 170, 76), dtype=float32)
# Coordinates:
#   * time         (time) datetime64[ns] 8B 2023-07-02T11:59:59.999999
#   * y            (y) float64 1kB 5.731e+04 5.753e+04 ... 9.427e+04 9.449e+04
#   * x            (x) float64 608B 3.473e+06 3.474e+06 ... 3.49e+06 3.49e+06
#     spatial_ref  int32 4B 6933
# Attributes:
#     nodata:   nan
#     scales:   1
#     offsets:  0

# %%
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(5,6))

cmap = mcolors.ListedColormap(["none", "#3E5697"])

wq_ds["water_mask"].plot(
    ax=ax,
    cmap=cmap,
    vmin=0,
    vmax=1,
    add_colorbar=False
)

year = wq_ds["water_mask"].time.dt.year.values.item()
plt.title(f"Five year average water mask for {year}");
plt.show()

# %% [markdown]
# Generate the water temperature water quality variables.

# %%
# %%time
from water_quality.mapping.temperature import water_temperature
wq_ds["water_temp"] = water_temperature(annual_data=annual_data, water_mask=wq_ds["water_mask"], compute=True)
wq_ds["water_temp"]
# Out:
# 2026-02-22 19:04:39,505 water_quality.mapping.temperature [INFO]: Processing water temperature annual composite ...
# 2026-02-22 19:04:49,801 water_quality.mapping.temperature [INFO]: 	Computing water temperature dataset ...
# 2026-02-22 19:05:29,939 water_quality.mapping.temperature [INFO]: Processing complete for water temperature dataset.
# CPU times: user 10.9 s, sys: 830 ms, total: 11.8 s
# Wall time: 50.4 s
# <xarray.Dataset> Size: 312kB
# Dimensions:          (time: 1, y: 170, x: 76)
# Coordinates:
#   * time             (time) datetime64[ns] 8B 2023-07-02T11:59:59.999999
#   * y                (y) float64 1kB 5.731e+04 5.753e+04 ... 9.427e+04 9.449e+04
#   * x                (x) float64 608B 3.473e+06 3.474e+06 ... 3.49e+06 3.49e+06
#     spatial_ref      int32 4B 6933
#     quantile         float64 8B 0.1
# Data variables:
#     tirs_st_ann_med  (time, y, x) float64 103kB nan nan nan nan ... nan nan nan
#     tirs_st_ann_min  (time, y, x) float64 103kB nan nan nan nan ... nan nan nan
#     tirs_st_ann_max  (time, y, x) float64 103kB nan nan nan nan ... nan nan nan

# %%
water_temp_bands = list(wq_ds["water_temp"].data_vars)

vmin = min([float(wq_ds["water_temp"][band].min()) for band in water_temp_bands])
vmax = max([float(wq_ds["water_temp"][band].max()) for band in water_temp_bands])

norm = mcolors.Normalize(vmin=vmin, vmax=vmax)
cmap = "coolwarm"

fig, ax = plt.subplots(1, 3, sharey=True, figsize=(15, 7))

wq_ds["water_temp"]["tirs_st_ann_min"].plot(ax=ax[0], cmap=cmap, norm=norm, add_colorbar=False)
ax[0].set_title(f"Minumum annual water temperature \n for {year}")

wq_ds["water_temp"]["tirs_st_ann_med"].plot(ax=ax[1], cmap=cmap, norm=norm, add_colorbar=False)
ax[1].set_title(f"Median annual water temperature \n for {year}")

im = wq_ds["water_temp"]["tirs_st_ann_max"].plot(ax=ax[2], cmap=cmap, norm=norm, add_colorbar=False)
ax[2].set_title(f"Maximum annual water temperature \n for {year}")

fig.colorbar(im, ax=ax, orientation='horizontal', fraction=.1)

plt.show()

# %% [markdown]
# Calculate the Floating Algae Index (FAI) for the available instruments.

# %%
# %%time
wq_ds["fai"] = geomedian_FAI(
    annual_data=annual_data,
    water_mask=wq_ds["water_mask"],
    compute=True,
)
gc.collect()
wq_ds["fai"]
# Out:
# 2026-02-22 19:05:31,010 water_quality.mapping.fai [INFO]: Calculating Geomedian FAI for available instruments ...
# 2026-02-22 19:05:31,011 water_quality.mapping.fai [INFO]: 	Calculating FAI for instrument: msi_agm ...
# 2026-02-22 19:05:31,019 water_quality.mapping.fai [INFO]: 	Calculating FAI for instrument: oli_agm ...
# 2026-02-22 19:05:31,059 water_quality.mapping.fai [INFO]: 	Computing FAI dataset ...
# 2026-02-22 19:05:31,509 water_quality.mapping.fai [INFO]: Geomedian FAI calculation complete.
# CPU times: user 367 ms, sys: 20.1 ms, total: 387 ms
# Wall time: 785 ms
# <xarray.Dataset> Size: 209kB
# Dimensions:      (time: 1, y: 170, x: 76)
# Coordinates:
#   * time         (time) datetime64[ns] 8B 2023-07-02T11:59:59.999999
#   * y            (y) float64 1kB 5.731e+04 5.753e+04 ... 9.427e+04 9.449e+04
#   * x            (x) float64 608B 3.473e+06 3.474e+06 ... 3.49e+06 3.49e+06
#     spatial_ref  int32 4B 6933
# Data variables:
#     msi_agm_fai  (time, y, x) float32 52kB nan nan nan nan ... nan nan nan nan
#     oli_agm_fai  (time, y, x) float32 52kB nan nan nan nan ... nan nan nan nan
#     agm_fai      (time, y, x) float32 52kB nan nan nan nan ... nan nan nan nan
#     tm_agm_fai   (time, y, x) float32 52kB nan nan nan nan ... nan nan nan nan

# %%
fai_bands = list(wq_ds["fai"].data_vars)

vmin = min([float(wq_ds["fai"][band].min()) for band in fai_bands])
vmax = max([float(wq_ds["fai"][band].max()) for band in fai_bands])

norm = mcolors.Normalize(vmin=vmin, vmax=vmax)
cmap = plt.cm.jet

fig, ax = plt.subplots(1, 3, sharey=True, figsize=(15, 7))
fig.suptitle(f"Floating Algae Index for {year}")

wq_ds["fai"]["msi_agm_fai"].plot(ax=ax[0], cmap=cmap, norm=norm, add_colorbar=False)
ax[0].set_title(f"FAI from MSI sensor")

wq_ds["fai"]["oli_agm_fai"].plot(ax=ax[1], cmap=cmap, norm=norm, add_colorbar=False)
ax[1].set_title(f"FAI from OLI sensor")

im = wq_ds["fai"]["agm_fai"].plot(ax=ax[2], cmap=cmap, norm=norm, add_colorbar=False)
ax[2].set_title(f"Mean weighted FAI")

fig.colorbar(im, ax=ax, orientation='horizontal', fraction=.1)

plt.show()

# %%
# %%time
# Calculate the clear water mask.
wq_ds["clear_water"] = clear_water_mask(
    annual_data=annual_data,
    water_frequency_threshold=WFTH,
    water_mask=wq_ds["water_mask"],
    agm_fai=wq_ds["fai"]["agm_fai"],
    compute=True,
)
gc.collect()
wq_ds["clear_water"]
# Out:
# 2026-02-22 19:05:32,115 water_quality.mapping.water_detection [INFO]: Calculating clear water mask ...
# 2026-02-22 19:05:32,125 water_quality.mapping.water_detection [INFO]: 	Computing clear water mask ...
# 2026-02-22 19:05:32,388 water_quality.mapping.water_detection [INFO]: Processing complete for clear water mask.
# CPU times: user 320 ms, sys: 26 μs, total: 320 ms
# Wall time: 551 ms
# <xarray.DataArray 'clear_water' (time: 1, y: 170, x: 76)> Size: 52kB
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]],
#       shape=(1, 170, 76), dtype=float32)
# Coordinates:
#   * time         (time) datetime64[ns] 8B 2023-07-02T11:59:59.999999
#   * y            (y) float64 1kB 5.731e+04 5.753e+04 ... 9.427e+04 9.449e+04
#   * x            (x) float64 608B 3.473e+06 3.474e+06 ... 3.49e+06 3.49e+06
#     spatial_ref  int32 4B 6933
# Attributes:
#     nodata:   nan
#     scales:   1
#     offsets:  0

# %%
fig, ax = plt.subplots(1, 2, sharey=True, figsize=(10,6))

cmap = mcolors.ListedColormap(["none", "#3E5697"])

wq_ds["water_mask"].plot(
    ax=ax[0],
    cmap=cmap,
    vmin=0,
    vmax=1,
    add_colorbar=False
)
ax[0].set_title(f"Five year average water mask {year}")


wq_ds["clear_water"].plot(
    ax=ax[1],
    cmap=cmap,
    vmin=0,
    vmax=1,
    add_colorbar=False
)
ax[1].set_title(f"Clear water mask for {year}")

plt.show()

# %% [markdown]
# Calculate the Normalized Difference Vegetation Index (NDVI) for the available instruments.

# %%
# %%time

wq_ds["ndvi"] = geomedian_NDVI(
    annual_data=annual_data,
    water_mask=wq_ds["water_mask"],
    compute=True,
)
gc.collect()
wq_ds["ndvi"]
# Out:
# 2026-02-22 19:05:32,852 water_quality.mapping.ndvi [INFO]: Calculating Geomedian NDVI for available instruments ...
# 2026-02-22 19:05:32,853 water_quality.mapping.ndvi [INFO]: 	Calculating NDVI for instrument: msi_agm ...
# 2026-02-22 19:05:32,860 water_quality.mapping.ndvi [INFO]: 	Calculating NDVI for instrument: oli_agm ...
# 2026-02-22 19:05:32,900 water_quality.mapping.ndvi [INFO]: 	Computing NDVI dataset ...
# 2026-02-22 19:05:33,022 water_quality.mapping.ndvi [INFO]: Geomedian NDVI calculation complete.
# CPU times: user 383 ms, sys: 10.2 ms, total: 393 ms
# Wall time: 475 ms
# <xarray.Dataset> Size: 209kB
# Dimensions:       (time: 1, y: 170, x: 76)
# Coordinates:
#   * time          (time) datetime64[ns] 8B 2023-07-02T11:59:59.999999
#   * y             (y) float64 1kB 5.731e+04 5.753e+04 ... 9.427e+04 9.449e+04
#   * x             (x) float64 608B 3.473e+06 3.474e+06 ... 3.49e+06 3.49e+06
#     spatial_ref   int32 4B 6933
# Data variables:
#     msi_agm_ndvi  (time, y, x) float32 52kB nan nan nan nan ... nan nan nan nan
#     oli_agm_ndvi  (time, y, x) float32 52kB nan nan nan nan ... nan nan nan nan
#     agm_ndvi      (time, y, x) float32 52kB nan nan nan nan ... nan nan nan nan
#     tm_agm_ndvi   (time, y, x) float32 52kB nan nan nan nan ... nan nan nan nan

# %%
ndvi_bands = list(wq_ds["ndvi"].data_vars)

vmin = min([float(wq_ds["ndvi"][band].min()) for band in ndvi_bands])
vmax = max([float(wq_ds["ndvi"][band].max()) for band in ndvi_bands])

norm = mcolors.Normalize(vmin=vmin, vmax=vmax)
cmap = "RdYlGn"

fig, ax = plt.subplots(1, 3, sharey=True, figsize=(15, 7))
fig.suptitle(f"NDVI for {year}")

wq_ds["ndvi"]["msi_agm_ndvi"].plot(ax=ax[0], cmap=cmap, norm=norm, add_colorbar=False)
ax[0].set_title(f"NDVI from MSI sensor")

wq_ds["ndvi"]["oli_agm_ndvi"].plot(ax=ax[1], cmap=cmap, norm=norm, add_colorbar=False)
ax[1].set_title(f"NDVI from OLI sensor")

im = wq_ds["ndvi"]["agm_ndvi"].plot(ax=ax[2], cmap=cmap, norm=norm, add_colorbar=False)
ax[2].set_title(f"Mean weighted NDVI")

fig.colorbar(im, ax=ax, orientation='horizontal', fraction=.1)

plt.show()

# %% [markdown]
# Apply Rayleigh correction to the available instruments.

# %%
annual_data = apply_R_correction(
    instrument_data=annual_data,
    water_mask=wq_ds["water_mask"],
    compute=False,
    drop=True,
)
gc.collect()
# Out:
# 2026-02-22 19:05:33,632 water_quality.mapping.pixel_correction [WARNING]: R correction not implemented for instrument: wofs_ann
# 2026-02-22 19:05:33,632 water_quality.mapping.pixel_correction [INFO]: Applying R correction for instrument: oli_agm
# 2026-02-22 19:05:33,660 water_quality.mapping.pixel_correction [WARNING]: Variable oli01_agm expected but not found in the dataset - (non-fatal error) for instrument oli_agm
# 2026-02-22 19:05:33,661 water_quality.mapping.pixel_correction [INFO]: R correction complete for oli_agm.
# 2026-02-22 19:05:33,661 water_quality.mapping.pixel_correction [INFO]: Applying R correction for instrument: msi_agm
# 2026-02-22 19:05:33,688 water_quality.mapping.pixel_correction [WARNING]: Variable msi01_agm expected but not found in the dataset - (non-fatal error) for instrument msi_agm
# 2026-02-22 19:05:33,714 water_quality.mapping.pixel_correction [INFO]: R correction complete for msi_agm.
# 2026-02-22 19:05:33,714 water_quality.mapping.pixel_correction [WARNING]: R correction not implemented for instrument: tirs
# 18236

# %% [markdown]
# Calculate the Hue for the available instruments.

# %%
# %%time
wq_ds["hue"] = geomedian_hue(
    annual_data=annual_data,
    clear_water_mask=wq_ds["clear_water"],
    compute=True,
)
gc.collect()
wq_ds["hue"]
# Out:
# 2026-02-22 19:05:34,004 water_quality.mapping.hue [INFO]: Calculating Geomedian Hue for available instruments ...
# 2026-02-22 19:05:34,006 water_quality.mapping.hue [INFO]: 	Calculating Hue for instrument: msi_agm ...
# 2026-02-22 19:05:34,103 water_quality.mapping.hue [INFO]: 	Calculating Hue for instrument: oli_agm ...
# 2026-02-22 19:05:34,104 water_quality.mapping.hue [ERROR]: Aborting hue calculation for instrument oli_agm due to lack of necessary data bands
# 2026-02-22 19:05:34,146 water_quality.mapping.hue [INFO]: 	Computing Hue dataset ...
# 2026-02-22 19:05:34,392 water_quality.mapping.hue [INFO]: Geomedian Hue calculation complete.
# CPU times: user 467 ms, sys: 10.8 ms, total: 477 ms
# Wall time: 663 ms
# <xarray.Dataset> Size: 364kB
# Dimensions:      (time: 1, y: 170, x: 76)
# Coordinates:
#   * time         (time) datetime64[ns] 8B 2023-07-02T11:59:59.999999
#   * y            (y) float64 1kB 5.731e+04 5.753e+04 ... 9.427e+04 9.449e+04
#   * x            (x) float64 608B 3.473e+06 3.474e+06 ... 3.49e+06 3.49e+06
#     spatial_ref  int32 4B 6933
# Data variables:
#     msi_agm_hue  (time, y, x) float64 103kB nan nan nan nan ... nan nan nan nan
#     oli_agm_hue  (time, y, x) float32 52kB nan nan nan nan ... nan nan nan nan
#     agm_hue      (time, y, x) float64 103kB nan nan nan nan ... nan nan nan nan
#     tm_agm_hue   (time, y, x) float64 103kB nan nan nan nan ... nan nan nan nan

# %%
hue_bands = list(wq_ds["hue"].data_vars)

# vmin = min([float(wq_ds["hue"][band].min()) for band in hue_bands])
vmin = 0
# vmax = max([float(wq_ds["hue"][band].max()) for band in hue_bands])
vmax = 360

norm = mcolors.Normalize(vmin=vmin, vmax=vmax)
cmap = "hsv"

fig, ax = plt.subplots(1, 3, sharey=True, figsize=(15, 7))
fig.suptitle(f"Hue for {year}")

wq_ds["hue"]["msi_agm_hue"].plot(ax=ax[0], cmap=cmap, norm=norm, add_colorbar=False)
ax[0].set_title(f"Hue from MSI sensor")

wq_ds["hue"]["oli_agm_hue"].plot(ax=ax[1], cmap=cmap, norm=norm, add_colorbar=False)
ax[1].set_title(f"Hue from OLI sensor")

im = wq_ds["hue"]["agm_hue"].plot(ax=ax[2], cmap=cmap, norm=norm, add_colorbar=False)
ax[2].set_title(f"Mean weighted geomedian Hue")

fig.colorbar(im, ax=ax, orientation='horizontal', fraction=.1)

plt.show()

# %% [markdown]
# Run Optical Water Type classification.

# %%
# %%time
wq_ds["owt"] = run_OWT(
    instrument_data=annual_data,
    clear_water_mask=wq_ds["clear_water"],
    compute=True,
)
gc.collect()
wq_ds["owt"]
# Out:
# 2026-02-22 19:05:34,964 water_quality.mapping.optical_water_type [INFO]: Running OWT classification for instrument: oli_agm ...
# 2026-02-22 19:05:34,976 water_quality.mapping.optical_water_type [INFO]: Calculating Optical Water Type (OWT) for instrument: oli
# 2026-02-22 19:05:35,255 water_quality.mapping.optical_water_type [INFO]: Running OWT classification for instrument: msi_agm ...
# 2026-02-22 19:05:35,268 water_quality.mapping.optical_water_type [INFO]: Calculating Optical Water Type (OWT) for instrument: msi
# 2026-02-22 19:05:35,561 water_quality.mapping.optical_water_type [INFO]: 	Computing OWT  ...
# 2026-02-22 19:05:36,533 water_quality.mapping.optical_water_type [INFO]: OWT classification complete.
# CPU times: user 1.14 s, sys: 22 ms, total: 1.17 s
# Wall time: 1.86 s
# <xarray.Dataset> Size: 209kB
# Dimensions:      (time: 1, y: 170, x: 76)
# Coordinates:
#   * time         (time) datetime64[ns] 8B 2023-07-02T11:59:59.999999
#   * y            (y) float64 1kB 5.731e+04 5.753e+04 ... 9.427e+04 9.449e+04
#   * x            (x) float64 608B 3.473e+06 3.474e+06 ... 3.49e+06 3.49e+06
#     spatial_ref  int32 4B 6933
# Data variables:
#     oli_agm_owt  (time, y, x) float32 52kB nan nan nan nan ... nan nan nan nan
#     msi_agm_owt  (time, y, x) float32 52kB nan nan nan nan ... nan nan nan nan
#     agm_owt      (time, y, x) float32 52kB nan nan nan nan ... nan nan nan nan
#     tm_agm_owt   (time, y, x) float32 52kB nan nan nan nan ... nan nan nan nan

# %%
colors = ["#D06562", "#ED6B65", "#FE796E", "#FF9F81", "#FFC296", "#FFE5AD", 
          "#DEF3FA", "#B9DEEE", "#97C6E0", "#74A7D2", "#6992BC", "#6380A6", "#4B5D82"]
levels = list(range(1, 15, 1))
labels = [f"OWT{i}" for i in levels]

cmap = mcolors.ListedColormap(colors)
norm = mcolors.BoundaryNorm(levels, cmap.N)

owt_bands = list(wq_ds["owt"].data_vars)

fig, ax = plt.subplots(1, 3, sharey=True, figsize=(15, 7))
fig.suptitle(f"Optical Water Types for {year}")

wq_ds["owt"]["msi_agm_owt"].plot(ax=ax[0], cmap=cmap, norm=norm, add_colorbar=False)
ax[0].set_title(f"Optical Water Types from MSI sensor")

wq_ds["owt"]["oli_agm_owt"].plot(ax=ax[1], cmap=cmap, norm=norm, add_colorbar=False)
ax[1].set_title(f"Optical Water Types from OLI sensor")

im = wq_ds["owt"]["agm_owt"].plot(ax=ax[2], cmap=cmap, norm=norm, add_colorbar=False)
ax[2].set_title(f"Combined Optical Water Types")

cbar_ticks = [i + 0.5 for i in levels]
cbar = fig.colorbar(im, ax=ax, ticks=cbar_ticks, orientation='horizontal', fraction=.1)
cbar.set_ticklabels(labels)

plt.show()

# %% [markdown]
# The following table provides the dominant characteristics of OWTs in inland waters from [Spyrakos et al. (2018))](https://doi.org/10.1002/lno.10674).
#
# | OWT   | Dominant characteristics                                                                 |
# |-------|-----------------------------------------------------------------------------------------|
# | OWT1  | Hypereutrophic waters with scum of cyanobacterial bloom and vegetation-like Rrs         |
# | OWT2  | Common case waters with diverse reflectance shape and marginal dominance of pigments and CDOM over inorganic suspended particles |
# | OWT3  | Clear waters                                                                            |
# | OWT4  | Turbid waters with high organic content                                                 |
# | OWT5  | Sediment-laden waters                                                                   |
# | OWT6  | Balanced effects of optically active constituents at shorter wavelength                 |
# | OWT7  | Highly productive waters with high cyanobacteria abundance and elevated reflectance at red/near-infrared spectral region |
# | OWT8  | Productive waters with cyanobacteria presence and with Rrs peak close to 700 nm        |
# | OWT9  | Optically neighboring to OWT2 waters but with higher Rrs at shorter wavelengths        |
# | OWT10 | CDOM-rich waters                                                                         |
# | OWT11 | Waters high in CDOM with cyanobacteria presence and high absorption efficiency by NAP  |
# | OWT12 | Turbid, moderately productive waters with cyanobacteria presence                        |
# | OWT13 | Very clear blue waters                                                                  |

# %%
# %%time
# Calculate TSM, TSI and Chla Water Quality variables
wq_ds["tsm_chla_tsi"], wq_vars_df = WQ_vars(
    annual_data=annual_data,
    water_mask=wq_ds["water_mask"],
    #stack_wq_vars=True,
    stack_wq_vars=False,
)
gc.collect()
wq_ds["tsm_chla_tsi"]
# Out:
# 2026-02-22 19:05:37,163 water_quality.mapping.algorithms [INFO]: Running TSM water quality algorithms ...
# 2026-02-22 19:05:37,240 water_quality.mapping.algorithms [INFO]: Harmonizing TSM water quality variables ...
# 2026-02-22 19:05:37,245 water_quality.mapping.algorithms [INFO]: 	Computing input dataset ...
# 2026-02-22 19:05:37,395 water_quality.mapping.algorithms [INFO]: 	Dask compute complete.
# 2026-02-22 19:05:37,458 water_quality.mapping.algorithms [INFO]: Normalizing TSM water quality variables ...
# 2026-02-22 19:05:37,473 water_quality.mapping.algorithms [INFO]: Running Chla water quality algorithms ...
# 2026-02-22 19:05:37,525 water_quality.mapping.algorithms [INFO]: Harmonizing Chla water quality variables ...
# 2026-02-22 19:05:37,530 water_quality.mapping.algorithms [INFO]: 	Computing input dataset ...
# 2026-02-22 19:05:37,713 water_quality.mapping.algorithms [INFO]: 	Dask compute complete.
# 2026-02-22 19:05:37,722 water_quality.mapping.algorithms [INFO]: Normalizing Chla water quality variables ...
# 2026-02-22 19:05:37,744 water_quality.mapping.algorithms [INFO]: Returning all water quality variables without stacking.
# CPU times: user 640 ms, sys: 19.1 ms, total: 659 ms
# Wall time: 875 ms
# <xarray.Dataset> Size: 2MB
# Dimensions:           (time: 1, y: 170, x: 76)
# Coordinates:
#   * time              (time) datetime64[ns] 8B 2023-07-02T11:59:59.999999
#   * y                 (y) float64 1kB 5.731e+04 5.753e+04 ... 9.449e+04
#   * x                 (x) float64 608B 3.473e+06 3.474e+06 ... 3.49e+06 3.49e+06
#     spatial_ref       int32 4B 6933
# Data variables: (12/22)
#     ndci_msi54        (time, y, x) float64 103kB nan nan nan nan ... nan nan nan
#     ndci_msi64        (time, y, x) float64 103kB nan nan nan nan ... nan nan nan
#     ndci_msi74        (time, y, x) float64 103kB nan nan nan nan ... nan nan nan
#     ndci_oli54        (time, y, x) float64 103kB nan nan nan nan ... nan nan nan
#     chla_toming_msi   (time, y, x) float64 103kB nan nan nan nan ... nan nan nan
#     chla_3bda_msi     (time, y, x) float64 103kB nan nan nan nan ... nan nan nan
#     ...                ...
#     tsm_lym_msi       (time, y, x) float64 103kB nan nan nan nan ... nan nan nan
#     tss_grb_msi       (time, y, x) float64 103kB nan nan nan nan ... nan nan nan
#     tss_grb_oli       (time, y, x) float64 103kB nan nan nan nan ... nan nan nan
#     tss_gr_msi        (time, y, x) float64 103kB nan nan nan nan ... nan nan nan
#     tss_gr_oli        (time, y, x) float64 103kB nan nan nan nan ... nan nan nan
#     spm_qiu_msi       (time, y, x) float64 103kB nan nan nan nan ... nan nan nan

# %%
# %%ignore
# fig, ax = plt.subplots(1, 2, sharey=True, figsize=(15, 7))
#
# wq_ds["tsm_chla_tsi"]["tsm"].plot(cmap="magma",robust=True, ax=ax[0])
# ax[0].set_title(f"Total Suspended Matter for {year}")
#
# wq_ds["tsm_chla_tsi"]["tsi"].plot(cmap='Spectral_r', robust=True, ax=ax[1])
# ax[1].set_title(f"Trophic State Index for {year}")
#
# plt.show()

# %% [markdown]
# Write the annual water quality variables to COG files and save the STAC metadata.

# %%
measurement_paths: list[str] = []
for wq_var_group in list(wq_ds.keys()):
    ds = wq_ds[wq_var_group]
    if isinstance(ds, xr.DataArray):
        name = ds.name
        ds = ds.to_dataset(name=name)

    # Save each band as COG
    fs = get_filesystem(output_directory, anon=False)
    bands = list(ds.data_vars.keys())
    for band in bands:
        da = ds[band]
        if da.size == 0:
            continue
        # Set attributes
        if "scales" not in list(da.attrs.keys()):
            da.attrs = dict(
                nodata=np.nan,
                scales=1,
                offsets=0,
                product_name=product_name,
                product_version=product_version,
            )
        else:
            da.attrs.update(
                dict(
                    product_name=product_name,
                    product_version=product_version,
                )
            )

        # Write COG
        cog_bytes = write_cog(
            geo_im=da,
            fname=":mem:",
            overwrite=True,
            nodata=da.attrs["nodata"],
            tags=da.attrs,
        )

        output_cog_url = get_wq_cog_url(
            output_directory=output_directory,
            tile_id=tile_id,
            temporal_id=temporal_id,
            band_name=band,
            product_name=product_name,
            product_version=product_version,
        )
        with fs.open(output_cog_url, "wb") as f:
            f.write(cog_bytes)
        log.info(f"Band {band} saved to {output_cog_url}")
        measurement_paths.append(output_cog_url)

    if wq_var_group == "tsm_chla_tsi":
        # Save WQ parameters table
        output_csv_url = get_wq_csv_url(
            output_directory=output_directory,
            tile_id=tile_id,
            temporal_id=temporal_id,
            product_name=product_name,
            product_version=product_version,
        )
        with fs.open(output_csv_url, mode="w") as f:
            wq_vars_df.to_csv(f, index=False)
        log.info(f"WQ parameters table saved to {output_csv_url}")

# Generate STAC metadata
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=UserWarning)
    log.info("Creating metadata STAC file ...")
    stac_file_url = prepare_dataset(  # noqa F841
        measurement_paths=measurement_paths,
    )

log.info(f"Successfully processed task: {task_id_str}")
# Out:
# 2026-02-22 19:05:38,094 __main__ [INFO]: Band water_mask saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_water_mask.tif
# 2026-02-22 19:05:38,098 __main__ [INFO]: Band tirs_st_ann_med saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_tirs_st_ann_med.tif
# 2026-02-22 19:05:38,102 __main__ [INFO]: Band tirs_st_ann_min saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_tirs_st_ann_min.tif
# 2026-02-22 19:05:38,106 __main__ [INFO]: Band tirs_st_ann_max saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_tirs_st_ann_max.tif
# 2026-02-22 19:05:38,109 __main__ [INFO]: Band msi_agm_fai saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_msi_agm_fai.tif
# 2026-02-22 19:05:38,112 __main__ [INFO]: Band oli_agm_fai saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_oli_agm_fai.tif
# 2026-02-22 19:05:38,115 __main__ [INFO]: Band agm_fai saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_agm_fai.tif
# 2026-02-22 19:05:38,118 __main__ [INFO]: Band tm_agm_fai saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_tm_agm_fai.tif
# 2026-02-22 19:05:38,121 __main__ [INFO]: Band clear_water saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_clear_water.tif
# 2026-02-22 19:05:38,124 __main__ [INFO]: Band msi_agm_ndvi saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_msi_agm_ndvi.tif
# 2026-02-22 19:05:38,126 __main__ [INFO]: Band oli_agm_ndvi saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_oli_agm_ndvi.tif
# 2026-02-22 19:05:38,129 __main__ [INFO]: Band agm_ndvi saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_agm_ndvi.tif
# 2026-02-22 19:05:38,132 __main__ [INFO]: Band tm_agm_ndvi saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_tm_agm_ndvi.tif
# 2026-02-22 19:05:38,136 __main__ [INFO]: Band msi_agm_hue saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_msi_agm_hue.tif
# 2026-02-22 19:05:38,138 __main__ [INFO]: Band oli_agm_hue saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_oli_agm_hue.tif
# 2026-02-22 19:05:38,142 __main__ [INFO]: Band agm_hue saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_agm_hue.tif
# 2026-02-22 19:05:38,145 __main__ [INFO]: Band tm_agm_hue saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_tm_agm_hue.tif
# 2026-02-22 19:05:38,148 __main__ [INFO]: Band oli_agm_owt saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_oli_agm_owt.tif
# 2026-02-22 19:05:38,150 __main__ [INFO]: Band msi_agm_owt saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_msi_agm_owt.tif
# 2026-02-22 19:05:38,153 __main__ [INFO]: Band agm_owt saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_agm_owt.tif
# 2026-02-22 19:05:38,156 __main__ [INFO]: Band tm_agm_owt saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_tm_agm_owt.tif
# 2026-02-22 19:05:38,159 __main__ [INFO]: Band ndci_msi54 saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_ndci_msi54.tif
# 2026-02-22 19:05:38,163 __main__ [INFO]: Band ndci_msi64 saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_ndci_msi64.tif
# 2026-02-22 19:05:38,166 __main__ [INFO]: Band ndci_msi74 saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_ndci_msi74.tif
# 2026-02-22 19:05:38,170 __main__ [INFO]: Band ndci_oli54 saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_ndci_oli54.tif
# 2026-02-22 19:05:38,173 __main__ [INFO]: Band chla_toming_msi saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_chla_toming_msi.tif
# 2026-02-22 19:05:38,177 __main__ [INFO]: Band chla_3bda_msi saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_chla_3bda_msi.tif
# 2026-02-22 19:05:38,180 __main__ [INFO]: Band chla_3bda_oli saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_chla_3bda_oli.tif
# 2026-02-22 19:05:38,184 __main__ [INFO]: Band chla_tebbs_msi saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_chla_tebbs_msi.tif
# 2026-02-22 19:05:38,188 __main__ [INFO]: Band chla_tebbs_oli saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_chla_tebbs_oli.tif
# 2026-02-22 19:05:38,191 __main__ [INFO]: Band chla_meris2b_msi saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_chla_meris2b_msi.tif
# 2026-02-22 19:05:38,195 __main__ [INFO]: Band chla_modis2b_msi saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_chla_modis2b_msi.tif
# 2026-02-22 19:05:38,199 __main__ [INFO]: Band ndssi_rg_msi saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_ndssi_rg_msi.tif
# 2026-02-22 19:05:38,202 __main__ [INFO]: Band ndssi_rg_oli saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_ndssi_rg_oli.tif
# 2026-02-22 19:05:38,206 __main__ [INFO]: Band ndssi_bnir_oli saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_ndssi_bnir_oli.tif
# 2026-02-22 19:05:38,209 __main__ [INFO]: Band ti_yu_oli saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_ti_yu_oli.tif
# 2026-02-22 19:05:38,213 __main__ [INFO]: Band tsm_lym_oli saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_tsm_lym_oli.tif
# 2026-02-22 19:05:38,216 __main__ [INFO]: Band tsm_lym_msi saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_tsm_lym_msi.tif
# 2026-02-22 19:05:38,220 __main__ [INFO]: Band tss_grb_msi saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_tss_grb_msi.tif
# 2026-02-22 19:05:38,224 __main__ [INFO]: Band tss_grb_oli saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_tss_grb_oli.tif
# 2026-02-22 19:05:38,228 __main__ [INFO]: Band tss_gr_msi saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_tss_gr_msi.tif
# 2026-02-22 19:05:38,231 __main__ [INFO]: Band tss_gr_oli saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_tss_gr_oli.tif
# 2026-02-22 19:05:38,235 __main__ [INFO]: Band spm_qiu_msi saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_spm_qiu_msi.tif
# 2026-02-22 19:05:38,237 __main__ [INFO]: WQ parameters table saved to test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y_water_quality_variables.csv
# 2026-02-22 19:05:38,237 __main__ [INFO]: Creating metadata STAC file ...
# 2026-02-22 19:05:38,334 water_quality.metadata.prepare_metadata [INFO]: Wrote dataset 2b0e5308-b9fc-5943-bc08-417e203b948d to /home/jovyan/dev/deafrica_water_quality/validation/LoadingData/test/wq_annual/1-0-0/x217/y077/2023--P1Y/wq_annual_x217y077_2023--P1Y.stac-item.json
# 2026-02-22 19:05:38,335 __main__ [INFO]: Successfully processed task: 2023--P1Y/x217/y077
